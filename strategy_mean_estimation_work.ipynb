# %%
# %load_ext autoreload
# %autoreload 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %aimport strategy
# %aimport mock_validation_server

# %%
val_server_1 = mock_validation_server.Validation(mock_validation_server.mean_loss,
                                                0.5, 0.005)
strategy_1 = strategy.Strategy(None, strategy.adaptive_mean_estimation_1, 
                              val_server_1)

# %%
strategy_1.do_strategy(phi_0 = -1, step_size = .01, tolerance = .01)

# %%
strategy_1.show_attempts()
# Out:
# /home/owen/.local/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
type(len(strategy_1.attempt_record))
# Out:
# int

# %%
val_server_2 = mock_validation_server.Validation(mock_validation_server.mean_loss,
                                                0.5, 0.1)
strategy_2 = strategy.Strategy(None, strategy.adaptive_mean_estimation_1, 
                              val_server_2)
strategy_2.do_strategy(phi_0 = -1, step_size = .01, tolerance = .01)
strategy_2.show_attempts()
